# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt

train_data  = genfromtxt('ccard.csv', delimiter = ',')
descriptions = open('ccard_descr.csv').read().split(',')
cases = train_data[:, 1:-1]#[ncases, nfeatures]
our_descriptions = descriptions[1:-1]
std_dev = np.apply_along_axis(np.std, 0, cases)
mean = np.apply_along_axis(np.mean, 0, cases)
print(train_data[:,-1])
n, bins, patches = plt.hist(train_data[:,-1], 2, normed=0, facecolor='red',)
plt.show()
for i in range(cases.shape[1]):
    print('%r:======================================================================' %(i))
    print(our_descriptions[i])
    print("std_dev", std_dev[i])
    print("mean", mean[i])
    print("min", np.min(cases[:,i]))
    print("max", np.max(cases[:,i]))
    #print("column", cases[:,i])
    n, bins, patches = plt.hist(cases[:,i], 50, normed=0, facecolor='red',)
    plt.show()
# Out:
# [ 1.  1.  0. ...,  1.  1.  1.]
# 0:======================================================================
# LIMIT_BAL
# std_dev 129745.499088
# mean 167484.322667
# min 10000.0
# max 1000000.0
# 1:======================================================================
# SEX
# std_dev 0.489121043869
# mean 1.60373333333
# min 1.0
# max 2.0
# 2:======================================================================
# EDUCATION
# std_dev 0.790335487133
# mean 1.85313333333
# min 0.0
# max 6.0
# 3:======================================================================
# MARRIAGE
# std_dev 0.521960901047
# mean 1.55186666667
# min 0.0
# max 3.0
# 4:======================================================================
# AGE
# std_dev 9.21775043508
# mean 35.4855
# min 21.0
# max 79.0
# 5:======================================================================
# PAY_0
# std_dev 1.12378279782
# mean -0.0167
# min -2.0
# max 8.0
# 6:======================================================================
# PAY_2
# std_dev 1.19716601977
# mean -0.133766666667
# min -2.0
# max 8.0
# 7:======================================================================
# PAY_3
# std_dev 1.19684762049
# mean -0.1662
# min -2.0
# max 8.0
# 8:======================================================================
# PAY_4
# std_dev 1.1691191366
# mean -0.220666666667
# min -2.0
# max 8.0
# 9:======================================================================
# PAY_5
# std_dev 1.13316851939
# mean -0.2662
# min -2.0
# max 8.0
# 10:======================================================================
# PAY_6
# std_dev 1.14996845899
# mean -0.2911
# min -2.0
# max 8.0
# 11:======================================================================
# BILL_AMT1
# std_dev 73634.633301
# mean 51223.3309
# min -165580.0
# max 964511.0
# 12:======================================================================
# BILL_AMT2
# std_dev 71172.5825432
# mean 49179.0751667
# min -69777.0
# max 983931.0
# 13:======================================================================
# BILL_AMT3
# std_dev 69348.2315943
# mean 47013.1548
# min -157264.0
# max 1664089.0
# 14:======================================================================
# BILL_AMT4
# std_dev 64331.7839107
# mean 43262.9489667
# min -170000.0
# max 891586.0
# 15:======================================================================
# BILL_AMT5
# std_dev 60796.1424759
# mean 40311.4009667
# min -81334.0
# max 927171.0
# 16:======================================================================
# BILL_AMT6
# std_dev 59553.11496
# mean 38871.7604
# min -339603.0
# max 961664.0
# 17:======================================================================
# PAY_AMT1
# std_dev 16563.0042971
# mean 5663.5805
# min 0.0
# max 873552.0
# 18:======================================================================
# PAY_AMT2
# std_dev 23040.4863844
# mean 5921.1635
# min 0.0
# max 1684259.0
# 19:======================================================================
# PAY_AMT3
# std_dev 17606.668018
# mean 5225.6815
# min 0.0
# max 896040.0
# 20:======================================================================
# PAY_AMT4
# std_dev 15665.8986392
# mean 4826.07686667
# min 0.0
# max 621000.0
# 21:======================================================================
# PAY_AMT5
# std_dev 15278.0510386
# mean 4799.38763333
# min 0.0
# max 426529.0
# 22:======================================================================
# PAY_AMT6
# std_dev 17777.1694819
# mean 5215.50256667
# min 0.0
# max 528666.0
